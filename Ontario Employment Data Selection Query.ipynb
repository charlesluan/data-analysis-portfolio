# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('14100355.csv')
df
# Out:
# /Volumes/ExtendHFS/Anaconda/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        REF_DATE               GEO           DGUID  \
# 0       1976-01            Canada  2016A000011124
# 1       1976-01            Canada  2016A000011124
# 2       1976-01            Canada  2016A000011124
# 3       1976-01            Canada  2016A000011124
# 4       1976-01            Canada  2016A000011124
# ...         ...               ...             ...
# 587323  2021-12  British Columbia     2016A000259
# 587324  2021-12  British Columbia     2016A000259
# 587325  2021-12  British Columbia     2016A000259
# 587326  2021-12  British Columbia     2016A000259
# 587327  2021-12  British Columbia     2016A000259
#
#        North American Industry Classification System (NAICS)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587328 entries, 0 to 587327
# Data columns (total 17 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   REF_DATE                                               587328 non-null  object
#  1   GEO                                                    587328 non-null  object
#  2   DGUID                                                  587328 non-null  object
#  3   North American Industry Classification System (NAICS)  587328 non-null  object
#  4   Statistics                                             587328 non-null  object
#  5   Data type                                              587328 non-null  object
#  6   UOM                                                    587328 non-null  object
#  7   UOM_ID                                                 587328 non-null  int64
# ...

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    #print('{} - {}%'.format(col,pct_missing))
    print(col,pct_missing)
# Out:
# REF_DATE 0.0
# GEO 0.0
# DGUID 0.0
# North American Industry Classification System (NAICS) 0.0
# Statistics 0.0
# Data type 0.0
# UOM 0.0
# UOM_ID 0.0
# SCALAR_FACTOR 0.0
# SCALAR_ID 0.0
# VECTOR 0.0
# COORDINATE 0.0
# VALUE 0.32519988830772584
# STATUS 0.6748001116922742
# SYMBOL 1.0
# TERMINATED 1.0
# DECIMALS 0.0

# %%
df['REF_DATE'] = df['REF_DATE'].apply(pd.to_datetime)

# %%
df['Statistics'].unique()
# Out:
# array(['Estimate', 'Standard error of estimate',
#        'Standard error of month-to-month change',
#        'Standard error of year-over-year change'], dtype=object)

# %%
df['Data type'].unique()
# Out:
# array(['Seasonally adjusted', 'Trend-cycle', 'Unadjusted'], dtype=object)

# %%
df['GEO'].unique()
# Out:
# array(['Canada', 'Newfoundland and Labrador', 'Prince Edward Island',
#        'Nova Scotia', 'New Brunswick', 'Quebec', 'Ontario', 'Manitoba',
#        'Saskatchewan', 'Alberta', 'British Columbia'], dtype=object)

# %%
new_df = df[(df['GEO'] == 'Ontario') &
       (df['Data type'] == 'Seasonally adjusted') &
       (df['Statistics'] == 'Estimate') &
        (df['REF_DATE'] > '2001-12-31')]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4560 entries, 332557 to 586943
# Data columns (total 17 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   REF_DATE                                               4560 non-null   datetime64[ns]
#  1   GEO                                                    4560 non-null   object
#  2   DGUID                                                  4560 non-null   object
#  3   North American Industry Classification System (NAICS)  4560 non-null   object
#  4   Statistics                                             4560 non-null   object
#  5   Data type                                              4560 non-null   object
#  6   UOM                                                    4560 non-null   object
#  7   UOM_ID                                                 4560 non-null   int64
# ...

# %%
new_df['North American Industry Classification System (NAICS)'].nunique()
# Out:
# 19

# %%
#Counting how many rows it supposed to be, in last 20 years.  
# 20 Years * 12 Months * 19 Cateories
print(20*12*new_df['North American Industry Classification System (NAICS)'].nunique())
# Out:
# 4560

# %%
new_df
# Out:
#          REF_DATE      GEO        DGUID  \
# 332557 2002-01-01  Ontario  2016A000235
# 332562 2002-01-01  Ontario  2016A000235
# 332567 2002-01-01  Ontario  2016A000235
# 332572 2002-01-01  Ontario  2016A000235
# 332577 2002-01-01  Ontario  2016A000235
# ...           ...      ...          ...
# 586923 2021-12-01  Ontario  2016A000235
# 586928 2021-12-01  Ontario  2016A000235
# 586933 2021-12-01  Ontario  2016A000235
# 586938 2021-12-01  Ontario  2016A000235
# 586943 2021-12-01  Ontario  2016A000235
#
#        North American Industry Classification System (NAICS) Statistics  \
# 332557                     Total employed, all industries      Estimate
# 332562                             Goods-producing sector      Estimate
# 332567             Agriculture [111-112, 1100, 1151-1152]      Estimate
# 332572  Forestry, fishing, mining, quarrying, oil and ...      Estimate
# 332577                                     Utilities [22]      Estimate
# ...

# %%
new_df.to_csv('Ontario_2002_2021.csv', index=False)
